# %% [markdown]
# # JsonParser

# %%
from langchain_core.output_parsers import JsonOutputParser
from langchain_core.prompts import PromptTemplate
from langchain_groq import ChatGroq
from dotenv import load_dotenv
import os

load_dotenv()
# Out:
# C:\Users\saish\AppData\Roaming\Python\Python314\site-packages\langchain_core\_api\deprecation.py:26: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1.fields import FieldInfo as FieldInfoV1
# True

# %%
# Create Object of Json Parser

parser = JsonOutputParser()

# %%
# Create Prompt 
prompt = PromptTemplate(
    template = "Give me details about {topic} in JSON format.\n{format_instructions}",
    input_variables = ["topic"],
    partial_variables = {
        "format_instructions": parser.get_format_instructions()

    }
)

# %%
# Create LLm Object
llm = ChatGroq(model="llama-3.1-8b-instant")

# %%
# create chain to perform opration one by one
chain = prompt | llm | parser

result = chain.invoke({"topic": "Python"})
print(result)
# Out:
# {'name': 'Python', 'version': '3.10.12', 'release_date': 'October 24, 2022', 'creator': 'Guido van Rossum', 'paradigm': 'Object-oriented, multi-paradigm', 'dynamically_typed': True, 'platforms': ['Windows', 'macOS', 'Linux'], 'typing': 'Optional static typing with type hints', 'use_cases': ['Web development', 'Data analysis', 'Machine learning', 'Automation'], 'libraries': ['NumPy', 'Pandas', 'Matplotlib', 'Scikit-learn', 'TensorFlow', 'Keras'], 'application': ['Data Science', 'Web Development', 'Automation', 'Scientific Computing', 'Machine Learning']}

# %%
from pprint import pprint

pprint(result)
# Out:
# {'application': ['Data Science',
#                  'Web Development',
#                  'Automation',
#                  'Scientific Computing',
#                  'Machine Learning'],
#  'creator': 'Guido van Rossum',
#  'dynamically_typed': True,
#  'libraries': ['NumPy',
#                'Pandas',
#                'Matplotlib',
#                'Scikit-learn',
#                'TensorFlow',
#                'Keras'],
#  'name': 'Python',
#  'paradigm': 'Object-oriented, multi-paradigm',
#  'platforms': ['Windows', 'macOS', 'Linux'],
#  'release_date': 'October 24, 2022',
#  'typing': 'Optional static typing with type hints',
#  'use_cases': ['Web development',
#                'Data analysis',
#                'Machine learning',
#                'Automation'],
#  'version': '3.10.12'}
